# %%
# !pip install joblib scikit-learn
# !pip install pandas numpy
# Out:
# Requirement already satisfied: joblib in c:\program files\python310\lib\site-packages (1.5.1)
# Requirement already satisfied: scikit-learn in c:\program files\python310\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\program files\python310\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in c:\program files\python310\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\program files\python310\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pandas in c:\program files\python310\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy in c:\program files\python310\lib\site-packages (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\program files\python310\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\program files\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\program files\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score

from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import StandardScaler

# Load dataset
df = pd.read_csv("combined_augmented_dataset.csv")  # Replace with path

# Setup
disease_col = "diseases"
symptom_cols = [col for col in df.columns if col != disease_col]

import re

# Sanitize symptom column names
sanitized_mapping = {}
for col in symptom_cols:
    clean_col = re.sub(r'\W+', '_', col.strip())  # Replace non-alphanum with _
    sanitized_mapping[col] = clean_col

# Rename columns
df.rename(columns=sanitized_mapping, inplace=True)
symptom_cols = [sanitized_mapping[col] for col in symptom_cols]

# Filter singleton classes
class_counts = df[disease_col].value_counts()
valid_classes = class_counts[class_counts >= 2].index
df = df[df[disease_col].isin(valid_classes)].reset_index(drop=True)

X = df[symptom_cols].astype(np.float32)
y = df[disease_col]

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, stratify=y_encoded, test_size=0.2, random_state=42
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define models
models = {
    "RandomForest": RandomForestClassifier(n_estimators=100,max_depth=50, max_features='sqrt',  random_state=42)
}

# Train and evaluate
for name, model in models.items():
    print(f"\n🔍 Training {name}...")

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, target_names=le.classes_, zero_division=0)

    print(f"{name} Accuracy: {acc:.4f}")
    print(report)

    joblib.dump(model, f"{name}_model.pkl")

# Save shared artifacts
joblib.dump(le, "label_encoder.pkl")
joblib.dump(symptom_cols, "symptom_cols.pkl")
joblib.dump(scaler, "scaler.pkl")
# Out:
# 🔍 Training RandomForest...
# RandomForest Accuracy: 0.7640
#                                                           precision    recall  f1-score   support
#
#                  (vertigo) Paroymsal  Positional Vertigo       1.00      1.00      1.00         2
#                                                     AIDS       1.00      1.00      1.00         2
#                                                     Acne       1.00      1.00      1.00         2
#                                      Alcoholic hepatitis       1.00      1.00      1.00         3
#                                                  Allergy       1.00      1.00      1.00         2
#                                                Arthritis       1.00      1.00      1.00         2
#                                         Bronchial Asthma       1.00      0.50      0.67         2
#                                     Cervical spondylosis       1.00      1.00      1.00         2
#                                              Chicken pox       1.00      0.67      0.80         3
#                                      Chronic cholestasis       1.00      1.00      1.00         3
#                                              Common Cold       1.00      1.00      1.00         5
#                                                   Dengue       1.00      1.00      1.00         4
#                                                Diabetes        1.00      1.00      1.00         3
#                             Dimorphic hemmorhoids(piles)       1.00      1.00      1.00         2
#                                            Drug Reaction       1.00      1.00      1.00         2
#                                         Fungal infection       1.00      1.00      1.00         2
#                                                     GERD       1.00      1.00      1.00         2
#                                          Gastroenteritis       1.00      1.00      1.00         2
#                                             Heart attack       1.00      1.00      1.00         2
#                                              Hepatitis B       1.00      1.00      1.00         4
#                                              Hepatitis C       1.00      1.00      1.00         2
#                                              Hepatitis D       0.67      0.67      0.67         3
#                                              Hepatitis E       0.67      0.50      0.57         4
#                                            Hypertension        1.00      1.00      1.00         2
#                                          Hyperthyroidism       1.00      1.00      1.00         3
#                                             Hypoglycemia       1.00      1.00      1.00         4
#                                           Hypothyroidism       1.00      1.00      1.00         4
#                                                 Impetigo       1.00      1.00      1.00         2
#                                                 Jaundice       0.50      1.00      0.67         3
#                                                  Malaria       0.75      1.00      0.86         3
#                                                 Migraine       1.00      1.00      1.00         3
#                                          Osteoarthristis       1.00      1.00      1.00         2
#                             Paralysis (brain hemorrhage)       1.00      1.00      1.00         2
#                                      Peptic ulcer diseae       1.00      1.00      1.00         2
#                                                Pneumonia       1.00      0.67      0.80         3
#                                                Psoriasis       1.00      1.00      1.00         2
#                                             Tuberculosis       1.00      0.80      0.89         5
#                                                  Typhoid       1.00      1.00      1.00         3
#                                  Urinary tract infection       1.00      1.00      1.00         2
#                                           Varicose veins       1.00      1.00      1.00         3
#                                abdominal aortic aneurysm       0.67      1.00      0.80         2
#                                         abdominal hernia       1.00      1.00      1.00         3
#                                          abscess of nose       0.67      0.67      0.67         3
#                                      abscess of the lung       1.00      0.50      0.67         2
#                                   abscess of the pharynx       1.00      0.67      0.80         3
#                                     acanthosis nigricans       0.50      1.00      0.67         2
#                                                acariasis       1.00      1.00      1.00         2
#                                                achalasia       1.00      1.00      1.00         2
#                                                     acne       1.00      0.33      0.50         3
#                                        actinic keratosis       1.00      0.33      0.50         3
#                                      acute bronchiolitis       0.80      1.00      0.89         4
#                                         acute bronchitis       0.67      0.50      0.57         4
#                                       acute bronchospasm       1.00      0.67      0.80         3
#                    acute fatty liver of pregnancy (aflp)       0.00      0.00      0.00         2
#                                           acute glaucoma       0.25      0.33      0.29         3
#                                      acute kidney injury       0.50      1.00      0.67         3
#                                       acute otitis media       1.00      0.67      0.80         3
#                                       acute pancreatitis       0.80      1.00      0.89         4
#               acute respiratory distress syndrome (ards)       1.00      0.67      0.80         3
#                                          acute sinusitis       1.00      0.67      0.80         3
#                                    acute stress reaction       0.04      0.67      0.07         3
#                      adhesive capsulitis of the shoulder       0.50      0.50      0.50         2
#                                      adjustment reaction       0.75      1.00      0.86         3
#                                          adrenal adenoma       1.00      0.50      0.67         2
#                                           adrenal cancer       0.40      1.00      0.57         2
#                                            alcohol abuse       0.67      0.67      0.67         3
#                                     alcohol intoxication       0.21      1.00      0.35         3
#                                       alcohol withdrawal       0.67      0.67      0.67         3
#                                  alcoholic liver disease       1.00      0.67      0.80         3
#                                                  allergy       1.00      0.33      0.50         3
#                                       allergy to animals       0.25      1.00      0.40         2
#                                                 alopecia       0.75      1.00      0.86         3
#                                        alzheimer disease       0.75      1.00      0.86         3
#                                                amblyopia       1.00      1.00      1.00         2
#                                              amyloidosis       1.00      1.00      1.00         2
#                      amyotrophic lateral sclerosis (als)       1.00      0.50      0.67         2
#                                             anal fissure       1.00      1.00      1.00         3
#                                             anal fistula       1.00      1.00      1.00         2
#                                                   anemia       1.00      1.00      1.00         3
#                     anemia due to chronic kidney disease       1.00      0.50      0.67         2
#                                 anemia due to malignancy       1.00      0.50      0.67         2
#                                anemia of chronic disease       1.00      0.50      0.67         2
#                                                   angina       1.00      1.00      1.00         3
#                                   ankylosing spondylitis       1.00      0.67      0.80         3
#                                                  anxiety       1.00      0.75      0.86         4
#                                     aortic valve disease       1.00      1.00      1.00         3
#                                                  aphakia       1.00      1.00      1.00         2
#                                           aphthous ulcer       0.40      0.67      0.50         3
#                                          aplastic anemia       1.00      1.00      1.00         2
#                                             appendicitis       1.00      0.67      0.80         3
#                                               arrhythmia       0.00      0.00      0.00         3
#                                     arthritis of the hip       1.00      1.00      1.00         4
#                                    ascending cholangitis       0.00      0.00      0.00         2
#                                        asperger syndrome       0.33      0.33      0.33         3
#                                            aspergillosis       1.00      1.00      1.00         2
#                                                   asthma       0.75      1.00      0.86         3
#                                              astigmatism       1.00      1.00      1.00         3
#                                              atelectasis       1.00      0.50      0.67         2
#                                           athlete's foot       0.50      0.33      0.40         3
#                                           atonic bladder       1.00      1.00      1.00         2
#                                      atrial fibrillation       0.50      0.33      0.40         3
#                                           atrial flutter       0.75      1.00      0.86         3
#                                  atrophic skin condition       0.75      1.00      0.86         3
#                                       atrophic vaginitis       1.00      0.33      0.50         3
#                         atrophy of the corpus cavernosum       1.00      0.50      0.67         2
#          attention deficit hyperactivity disorder (adhd)       0.33      0.33      0.33         3
#                                                   autism       1.00      0.33      0.50         3
#                        autonomic nervous system disorder       1.00      1.00      1.00         2
#                                       avascular necrosis       1.00      1.00      1.00         2
#                                                balanitis       1.00      0.67      0.80         3
#                                               bell palsy       0.67      0.67      0.67         3
#                                       benign kidney cyst       1.00      0.33      0.50         3
#             benign paroxysmal positional vertical (bppv)       1.00      1.00      1.00         3
#                       benign prostatic hyperplasia (bph)       1.00      1.00      1.00         4
#                    benign vaginal discharge (leukorrhea)       1.00      0.67      0.80         3
#                                         bipolar disorder       0.50      0.33      0.40         3
#                                             birth trauma       0.00      0.00      0.00         2
#                                           bladder cancer       1.00      1.00      1.00         3
#                                         bladder disorder       0.50      0.67      0.57         3
#                                      bladder obstruction       1.00      1.00      1.00         3
#                                              blepharitis       0.29      0.67      0.40         3
#                                            blepharospasm       1.00      1.00      1.00         2
#                                              bone cancer       1.00      0.50      0.67         2
#                                            bone disorder       1.00      1.00      1.00         3
#                              bone spur of the calcaneous       0.00      0.00      0.00         2
#                                        brachial neuritis       0.50      0.33      0.40         3
#                                             brain cancer       1.00      0.67      0.80         3
#                                            breast cancer       0.50      1.00      0.67         2
#                                              breast cyst       1.00      0.50      0.67         2
#                              breast infection (mastitis)       1.00      1.00      1.00         3
#                                             broken tooth       0.75      1.00      0.86         3
#                                                   bunion       1.00      0.50      0.67         2
#                                                     burn       1.00      0.50      0.67         2
#                                                 bursitis       1.00      0.50      0.67         4
#                                                   callus       0.75      1.00      0.86         3
#                                carbon monoxide poisoning       1.00      0.50      0.67         2
#                                       carcinoid syndrome       1.00      1.00      1.00         2
#                                           cardiac arrest       1.00      0.33      0.50         3
#                                           cardiomyopathy       0.50      0.67      0.57         3
#                                   carpal tunnel syndrome       1.00      0.75      0.86         4
#                                      cat scratch disease       1.00      1.00      1.00         2
#                                                 cataract       0.50      0.33      0.40         3
#                                           celiac disease       0.67      1.00      0.80         2
#                           cellulitis or abscess of mouth       0.60      1.00      0.75         3
#                                  central atherosclerosis       1.00      1.00      1.00         2
#                 central retinal artery or vein occlusion       0.40      1.00      0.57         2
#                                           cerebral edema       0.25      0.50      0.33         2
#                                           cerebral palsy       1.00      1.00      1.00         2
#                                          cervical cancer       0.50      1.00      0.67         2
#                                        cervical disorder       0.67      1.00      0.80         2
#                                               cervicitis       1.00      1.00      1.00         3
#                                                chalazion       0.50      0.33      0.40         3
#                                               chickenpox       0.33      0.50      0.40         2
#                                                chlamydia       0.50      0.50      0.50         2
#                                            cholecystitis       1.00      1.00      1.00         4
#                                      choledocholithiasis       1.00      0.67      0.80         3
#                                            cholesteatoma       1.00      0.50      0.67         2
#                            chondromalacia of the patella       1.00      1.00      1.00         2
#                                          chorioretinitis       0.22      1.00      0.36         2
#                                        chronic back pain       1.00      1.00      1.00         3
#                                     chronic constipation       1.00      1.00      1.00         3
#                                         chronic glaucoma       0.00      0.00      0.00         3
# chronic inflammatory demyelinating polyneuropathy (cidp)       1.00      1.00      1.00         2
#                                   chronic kidney disease       1.00      1.00      1.00         2
#                                        chronic knee pain       0.75      1.00      0.86         3
#             chronic obstructive pulmonary disease (copd)       1.00      0.33      0.50         3
#                                     chronic otitis media       1.00      0.67      0.80         3
#                                    chronic pain disorder       0.67      0.67      0.67         3
#                                     chronic pancreatitis       0.60      1.00      0.75         3
#                                  chronic rheumatic fever       1.00      0.33      0.50         3
#                                        chronic sinusitis       1.00      0.67      0.80         3
#                                            chronic ulcer       1.00      1.00      1.00         2
#                                                cirrhosis       1.00      0.33      0.50         3
#                          coagulation (bleeding) disorder       1.00      1.00      1.00         2
#                                                cold sore       1.00      1.00      1.00         3
#                                            colonic polyp       1.00      0.67      0.80         3
#                                        colorectal cancer       1.00      0.50      0.67         2
#                                              common cold       1.00      0.33      0.50         3
#                           complex regional pain syndrome       0.75      0.75      0.75         4
#                                               concussion       1.00      1.00      1.00         4
#                                         conduct disorder       1.00      0.67      0.80         3
#                                  conductive hearing loss       0.75      1.00      0.86         3
#                                  congenital heart defect       1.00      1.00      1.00         2
#                         congenital malformation syndrome       1.00      1.00      1.00         2
#                                           conjunctivitis       0.67      0.67      0.67         3
#                            conjunctivitis due to allergy       1.00      0.75      0.86         4
#                           conjunctivitis due to bacteria       1.00      0.50      0.67         2
#                              conjunctivitis due to virus       0.38      1.00      0.55         3
#                               connective tissue disorder       1.00      1.00      1.00         2
#                                       contact dermatitis       0.60      1.00      0.75         3
#                                      conversion disorder       0.67      1.00      0.80         2
#                                         cornea infection       0.50      0.33      0.40         3
#                                         corneal abrasion       1.00      0.33      0.50         3
#                                         corneal disorder       1.00      0.33      0.50         3
#                                 coronary atherosclerosis       1.00      0.33      0.50         3
#                                      cranial nerve palsy       0.67      0.67      0.67         3
#                                            crohn disease       1.00      0.33      0.50         3
#                                                    croup       1.00      1.00      1.00         3
#                                          crushing injury       0.67      1.00      0.80         2
#                                           cryptococcosis       1.00      1.00      1.00         2
#                                           cryptorchidism       0.67      1.00      0.80         2
#                                         cushing syndrome       1.00      1.00      1.00         2
#                                       cyst of the eyelid       1.00      1.00      1.00         2
#                                          cystic fibrosis       1.00      1.00      1.00         2
#                                            cysticercosis       0.67      1.00      0.80         2
#                                                 cystitis       1.00      0.75      0.86         4
#                                      de quervain disease       1.00      0.67      0.80         3
#                                          decubitus ulcer       0.50      1.00      0.67         2
#                               deep vein thrombosis (dvt)       1.00      1.00      1.00         3
#                                degenerative disc disease       0.60      1.00      0.75         3
#                                                 delirium       0.67      0.67      0.67         3
#                                                 dementia       1.00      0.67      0.80         3
#                                             dengue fever       1.00      1.00      1.00         2
#                                            dental caries       0.75      0.75      0.75         4
#                                               depression       0.75      0.75      0.75         4
#                           dermatitis due to sun exposure       1.00      0.67      0.80         3
#                                 developmental disability       0.75      1.00      0.86         3
#                                    deviated nasal septum       1.00      0.67      0.80         3
#                                                 diabetes       1.00      1.00      1.00         2
#                                       diabetes insipidus       0.00      0.00      0.00         2
#                                    diabetic ketoacidosis       0.50      0.67      0.57         3
#                                  diabetic kidney disease       1.00      1.00      1.00         2
#                           diabetic peripheral neuropathy       0.75      1.00      0.86         3
#                                     diabetic retinopathy       0.50      0.33      0.40         3
#                                              diaper rash       1.00      1.00      1.00         3
#                                 dislocation of the ankle       0.67      1.00      0.80         2
#                                 dislocation of the elbow       1.00      1.00      1.00         3
#                                dislocation of the finger       0.50      0.50      0.50         2
#                                  dislocation of the foot       1.00      1.00      1.00         2
#                                   dislocation of the hip       0.67      1.00      0.80         2
#                                  dislocation of the knee       1.00      0.50      0.67         2
#                               dislocation of the patella       0.67      1.00      0.80         2
#                              dislocation of the shoulder       0.67      1.00      0.80         2
#                              dislocation of the vertebra       0.67      1.00      0.80         2
#                                 dislocation of the wrist       1.00      1.00      1.00         2
#                                    dissociative disorder       1.00      1.00      1.00         2
#                                           diverticulitis       1.00      1.00      1.00         4
#                                           diverticulosis       0.75      1.00      0.86         3
#                                            down syndrome       1.00      1.00      1.00         2
#                                               drug abuse       0.67      0.67      0.67         3
#                                drug abuse (barbiturates)       1.00      1.00      1.00         2
#                                     drug abuse (cocaine)       1.00      0.33      0.50         3
#                             drug abuse (methamphetamine)       1.00      1.00      1.00         3
#                                     drug abuse (opioids)       0.38      1.00      0.55         3
#                         drug poisoning due to medication       1.00      1.00      1.00         3
#                                            drug reaction       0.67      0.50      0.57         4
#                                          drug withdrawal       0.50      0.33      0.40         3
#                                 dry eye of unknown cause       0.67      0.67      0.67         3
#                                         dumping syndrome       1.00      0.50      0.67         2
#                                              dyshidrosis       1.00      0.50      0.67         2
#                                       dysthymic disorder       1.00      1.00      1.00         3
#                                          ear drum damage       1.00      0.33      0.50         3
#                                        ear wax impaction       0.50      1.00      0.67         3
#                                          eating disorder       1.00      1.00      1.00         3
#                                        ectopic pregnancy       0.75      1.00      0.86         3
#                                                ectropion       0.50      1.00      0.67         2
#                                                   eczema       1.00      0.25      0.40         4
#                                          edward syndrome       1.00      1.00      1.00         2
#                                                emphysema       0.00      0.00      0.00         2
#                                                  empyema       0.00      0.00      0.00         2
#                                             encephalitis       1.00      1.00      1.00         2
#                                             endocarditis       0.50      0.50      0.50         2
#                                       endometrial cancer       1.00      0.50      0.67         2
#                                  endometrial hyperplasia       1.00      1.00      1.00         2
#                                            endometriosis       1.00      1.00      1.00         3
#                                          endophthalmitis       0.67      1.00      0.80         2
#                  envenomation from spider or animal bite       0.33      0.33      0.33         3
#                                               ependymoma       1.00      0.50      0.67         2
#                                             epididymitis       0.75      1.00      0.86         3
#                                      epidural hemorrhage       0.00      0.00      0.00         2
#                                                 epilepsy       1.00      1.00      1.00         3
#                                     erectile dysfunction       1.00      1.00      1.00         3
#                                      erythema multiforme       1.00      1.00      1.00         2
#                                        esophageal cancer       1.00      1.00      1.00         2
#                                       esophageal varices       1.00      1.00      1.00         2
#                                              esophagitis       1.00      0.75      0.86         4
#                                         essential tremor       1.00      0.67      0.80         3
#               eustachian tube dysfunction (ear disorder)       1.00      1.00      1.00         3
#                           extrapyramidal effect of drugs       1.00      0.50      0.67         2
#                                   eye alignment disorder       1.00      1.00      1.00         3
#                                      factitious disorder       1.00      1.00      1.00         2
#                               female genitalia infection       1.00      0.67      0.80         3
#                      female infertility of unknown cause       1.00      1.00      1.00         2
#                                   fetal alcohol syndrome       0.67      1.00      0.80         2
#                                             fibroadenoma       1.00      1.00      1.00         2
#                               fibrocystic breast disease       1.00      1.00      1.00         2
#                                             fibromyalgia       0.75      1.00      0.86         3
#                                                flat feet       1.00      0.50      0.67         2
#                                                 floaters       0.50      0.50      0.50         2
#                                                      flu       0.67      0.67      0.67         3
#                                           fluid overload       1.00      0.33      0.50         3
#                                        folate deficiency       0.33      0.50      0.40         2
#                                             food allergy       0.50      0.33      0.40         3
#                                  foreign body in the ear       0.67      1.00      0.80         2
#                                  foreign body in the eye       1.00      1.00      1.00         3
#               foreign body in the gastrointestinal tract       1.00      1.00      1.00         2
#                                 foreign body in the nose       1.00      1.00      1.00         2
#                               foreign body in the throat       1.00      0.67      0.80         3
#                               foreign body in the vagina       0.50      1.00      0.67         2
#                                    fracture of the ankle       1.00      0.67      0.80         3
#                                      fracture of the arm       0.50      0.33      0.40         3
#                             fracture of the facial bones       0.60      1.00      0.75         3
#                                   fracture of the finger       0.33      0.50      0.40         2
#                                     fracture of the foot       0.67      1.00      0.80         2
#                                     fracture of the hand       1.00      1.00      1.00         3
#                                      fracture of the jaw       1.00      1.00      1.00         2
#                                      fracture of the leg       0.67      0.67      0.67         3
#                                     fracture of the neck       1.00      1.00      1.00         2
#                                  fracture of the patella       1.00      1.00      1.00         2
#                                   fracture of the pelvis       0.50      0.33      0.40         3
#                                      fracture of the rib       0.75      1.00      0.86         3
#                                 fracture of the shoulder       1.00      0.67      0.80         3
#                                    fracture of the skull       1.00      1.00      1.00         2
#                                 fracture of the vertebra       1.00      1.00      1.00         3
#                                         friedrich ataxia       0.50      0.50      0.50         2
#                                                frostbite       1.00      1.00      1.00         2
#                             fungal infection of the hair       0.50      0.25      0.33         4
#                             fungal infection of the skin       1.00      0.67      0.80         3
#                                   g6pd enzyme deficiency       0.00      0.00      0.00         2
#                            galactorrhea of unknown cause       1.00      0.50      0.67         2
#                                                gallstone       0.50      0.67      0.57         3
#                                            ganglion cyst       0.75      1.00      0.86         3
#                                             gas gangrene       1.00      1.00      1.00         2
#                                                gastritis       1.00      1.00      1.00         3
#                                     gastroduodenal ulcer       1.00      1.00      1.00         3
#                   gastroesophageal reflux disease (gerd)       0.75      1.00      0.86         3
#                              gastrointestinal hemorrhage       1.00      0.25      0.40         4
#                                            gastroparesis       1.00      0.67      0.80         3
#                                           genital herpes       1.00      1.00      1.00         3
#                                     gestational diabetes       1.00      0.50      0.67         2
#                                                 glaucoma       0.75      1.00      0.86         3
#                                glucocorticoid deficiency       1.00      1.00      1.00         2
#                                                   goiter       0.20      0.50      0.29         2
#                                                gonorrhea       1.00      1.00      1.00         2
#                                                     gout       0.50      0.50      0.50         4
#                                      granuloma inguinale       0.00      0.00      0.00         2
#                                           graves disease       1.00      1.00      1.00         3
#                                  guillain barre syndrome       1.00      0.50      0.67         2
#                                              gum disease       1.00      1.00      1.00         3
#                                             gynecomastia       1.00      0.67      0.80         3
#                                               hammer toe       1.00      1.00      1.00         2
#                                    hashimoto thyroiditis       0.67      1.00      0.80         2
#                                     head and neck cancer       0.75      1.00      0.86         3
#                                              head injury       1.00      1.00      1.00         3
#                           headache after lumbar puncture       1.00      0.67      0.80         3
#                                             heart attack       1.00      1.00      1.00         3
#                                              heart block       0.25      0.67      0.36         3
#                                          heart contusion       0.00      0.00      0.00         2
#                                            heart failure       1.00      1.00      1.00         3
#                                          heat exhaustion       0.50      0.33      0.40         3
#                                              heat stroke       1.00      1.00      1.00         2
#                                               hemangioma       0.67      0.67      0.67         3
#                                             hemarthrosis       0.67      1.00      0.80         2
#                                                 hematoma       1.00      1.00      1.00         2
#                                               hemiplegia       1.00      1.00      1.00         3
#                                          hemochromatosis       0.29      1.00      0.44         2
#                                         hemolytic anemia       1.00      0.50      0.67         2
#                                               hemophilia       1.00      1.00      1.00         2
#                                              hemorrhoids       1.00      1.00      1.00         3
#                                   hepatic encephalopathy       1.00      0.50      0.67         2
#                                              hepatitis A       0.75      1.00      0.86         3
#                                 hepatitis due to a toxin       0.60      1.00      0.75         3
#                                           herniated disk       0.50      0.33      0.40         3
#                                               herpangina       1.00      0.33      0.50         3
#                                            hiatal hernia       0.80      1.00      0.89         4
#                                 hidradenitis suppurativa       1.00      1.00      1.00         2
#                                      high blood pressure       1.00      1.00      1.00         2
#                                     hirschsprung disease       1.00      1.00      1.00         2
#                                                hirsutism       1.00      0.50      0.67         2
#                                           histoplasmosis       1.00      0.50      0.67         2
#                                         hormone disorder       1.00      1.00      1.00         2
#                                                      hpv       0.67      1.00      0.80         2
#             human immunodeficiency virus infection (hiv)       0.50      1.00      0.67         2
#                                       huntington disease       0.00      0.00      0.00         2
#                                        hydatidiform mole       1.00      0.50      0.67         2
#                                hydrocele of the testicle       0.60      1.00      0.75         3
#                                            hydrocephalus       1.00      0.67      0.80         3
#                                           hydronephrosis       1.00      0.67      0.80         3
#                                            hypercalcemia       1.00      0.50      0.67         2
#                                     hypercholesterolemia       1.00      0.50      0.67         2
#                                   hyperemesis gravidarum       0.50      1.00      0.67         3
#                                   hypergammaglobulinemia       1.00      1.00      1.00         2
#                                            hyperhidrosis       1.00      1.00      1.00         2
#                                             hyperkalemia       1.00      0.67      0.80         3
#                                           hyperlipidemia       1.00      1.00      1.00         2
#                                            hypernatremia       1.00      0.50      0.67         2
#                                                hyperopia       1.00      0.50      0.67         2
#                          hyperosmotic hyperketotic state       0.67      1.00      0.80         2
#                                hypertension of pregnancy       1.00      1.00      1.00         2
#                               hypertensive heart disease       1.00      1.00      1.00         3
#           hypertrophic obstructive cardiomyopathy (hocm)       0.00      0.00      0.00         2
#                                             hypocalcemia       1.00      1.00      1.00         2
#                                             hypoglycemia       0.50      1.00      0.67         4
#                                              hypokalemia       0.75      1.00      0.86         3
#                                             hyponatremia       1.00      1.00      1.00         3
#                                              hypothermia       1.00      0.50      0.67         2
#                                           hypothyroidism       1.00      0.50      0.67         2
#                                              hypovolemia       0.67      0.67      0.67         3
#                       idiopathic absence of menstruation       0.75      1.00      0.86         3
#                        idiopathic excessive menstruation       0.75      1.00      0.86         3
#                       idiopathic infrequent menstruation       1.00      1.00      1.00         2
#                     idiopathic irregular menstrual cycle       0.67      0.67      0.67         3
#                         idiopathic nonmenstrual bleeding       0.33      0.50      0.40         2
#                          idiopathic painful menstruation       1.00      0.67      0.80         3
#                                                    ileus       0.67      0.67      0.67         3
#                                                 impetigo       1.00      1.00      1.00         3
#                                 impulse control disorder       1.00      0.33      0.50         3
#                                              indigestion       1.00      0.33      0.50         3
#                                         induced abortion       0.60      1.00      0.75         3
#                                  infection of open wound       1.00      1.00      1.00         2
#                               infectious gastroenteritis       0.80      1.00      0.89         4
#                                         ingrown toe nail       0.75      1.00      0.86         3
#                                          inguinal hernia       1.00      0.67      0.80         3
#                                      injury of the ankle       1.00      0.67      0.80         3
#                                 injury to internal organ       0.50      0.50      0.50         2
#                                    injury to the abdomen       1.00      1.00      1.00         2
#                                        injury to the arm       0.50      0.50      0.50         4
#                                       injury to the face       1.00      1.00      1.00         3
#                                     injury to the finger       1.00      0.50      0.67         2
#                                       injury to the hand       1.00      1.00      1.00         3
#                                        injury to the hip       1.00      0.50      0.67         2
#                                       injury to the knee       1.00      1.00      1.00         2
#                                        injury to the leg       1.00      0.50      0.67         4
#                                   injury to the shoulder       1.00      0.67      0.80         3
#                                injury to the spinal cord       1.00      0.50      0.67         2
#                                      injury to the trunk       0.75      1.00      0.86         3
#                                              insect bite       1.00      0.33      0.50         3
#                                         insulin overdose       0.00      0.00      0.00         2
#                                interstitial lung disease       0.33      0.33      0.33         3
#                              intertrigo (skin condition)       0.67      1.00      0.80         2
#                                        intestinal cancer       1.00      1.00      1.00         2
#                                       intestinal disease       1.00      1.00      1.00         3
#                                 intestinal malabsorption       0.75      1.00      0.86         3
#                                   intestinal obstruction       1.00      1.00      1.00         3
#                                 intracerebral hemorrhage       0.60      1.00      0.75         3
#                                     intracranial abscess       1.00      0.50      0.67         2
#                                  intracranial hemorrhage       0.60      1.00      0.75         3
#                                          intussusception       1.00      1.00      1.00         2
#                                            iridocyclitis       1.00      0.67      0.80         3
#                                   iron deficiency anemia       1.00      1.00      1.00         4
#                                 irritable bowel syndrome       1.00      0.67      0.80         3
#                                    ischemia of the bowel       0.43      1.00      0.60         3
#                                   ischemic heart disease       1.00      0.67      0.80         3
#                                 itching of unknown cause       0.60      1.00      0.75         3
#                                             jaw disorder       0.75      1.00      0.86         3
#                                           joint effusion       1.00      0.67      0.80         3
#                            juvenile rheumatoid arthritis       1.00      1.00      1.00         2
#                                           kaposi sarcoma       0.50      1.00      0.67         2
#                                            kidney cancer       1.00      0.50      0.67         2
#          kidney disease due to longstanding hypertension       1.00      1.00      1.00         2
#                                           kidney failure       1.00      1.00      1.00         3
#                                             kidney stone       0.25      0.33      0.29         3
#                           knee ligament or meniscus tear       1.00      1.00      1.00         3
#                                            labyrinthitis       1.00      0.67      0.80         3
#                                      lactose intolerance       0.67      1.00      0.80         2
#                                               laryngitis       1.00      1.00      1.00         3
#                     lateral epicondylitis (tennis elbow)       0.25      0.67      0.36         3
#                                                 leukemia       1.00      0.50      0.67         2
#                                       lewy body dementia       1.00      1.00      1.00         2
#                                                     lice       1.00      1.00      1.00         2
#                                            lichen planus       1.00      0.50      0.67         2
#                                           lichen simplex       1.00      0.50      0.67         2
#                                                   lipoma       1.00      1.00      1.00         3
#                                             liver cancer       1.00      1.00      1.00         2
#                                            liver disease       0.80      1.00      0.89         4
#                                                  lumbago       0.75      1.00      0.86         3
#                                              lung cancer       0.67      0.67      0.67         3
#                                           lung contusion       1.00      0.50      0.67         2
#                                             lyme disease       1.00      1.00      1.00         3
#                                            lymphadenitis       1.00      0.67      0.80         3
#                                             lymphangitis       1.00      1.00      1.00         2
#                                               lymphedema       0.50      0.67      0.57         3
#                                 lymphogranuloma venereum       1.00      1.00      1.00         2
#                                                 lymphoma       1.00      1.00      1.00         3
#                                     macular degeneration       1.00      1.00      1.00         3
#                                     magnesium deficiency       1.00      0.50      0.67         2
#                                                  malaria       0.33      0.50      0.40         2
#                                 male genitalia infection       0.67      1.00      0.80         2
#                                   malignant hypertension       1.00      0.67      0.80         3
#                                          marijuana abuse       0.50      0.25      0.33         4
#                                               mastectomy       0.50      0.50      0.50         2
#                                              mastoiditis       1.00      0.50      0.67         2
#                                      meckel diverticulum       1.00      1.00      1.00         2
#                                                 melanoma       1.00      1.00      1.00         3
#                                          meniere disease       0.75      1.00      0.86         3
#                                               meningioma       0.00      0.00      0.00         2
#                                               meningitis       1.00      1.00      1.00         3
#                                                menopause       1.00      1.00      1.00         2
# ...
#                                   pulmonic valve disease       0.00      0.00      0.00         2
#                                           pyelonephritis       0.50      0.67      0.57         3
#                                         pyloric stenosis       0.00      0.00      0.00         2
#                                  pyogenic skin infection       1.00      0.67      0.80         3
#                                          raynaud disease       1.00      0.50      0.67         2
#                                       reactive arthritis       1.00      1.00      1.00         2
#                                          rectal disorder       0.75      1.00      0.86         3
#                                    restless leg syndrome       0.50      0.67      0.57         3
#                                       retinal detachment       0.20      0.33      0.25         3
#                   retinopathy due to high blood pressure       1.00      0.50      0.67         2
#                                           rhabdomyolysis       1.00      0.50      0.67         2
#                                          rheumatic fever       1.00      1.00      1.00         2
#                                     rheumatoid arthritis       1.00      1.00      1.00         3
#                             rocky mountain spotted fever       1.00      1.00      1.00         2
#                                                  rosacea       0.50      0.67      0.57         3
#                                      rotator cuff injury       0.00      0.00      0.00         2
#                                  salivary gland disorder       1.00      0.50      0.67         2
#                                              sarcoidosis       1.00      0.67      0.80         3
#                                                  scabies       1.00      1.00      1.00         3
#                                                     scar       0.50      0.33      0.40         3
#                                            scarlet fever       0.50      1.00      0.67         2
#                                            schizophrenia       0.00      0.00      0.00         3
#                                                 sciatica       0.75      1.00      0.86         3
#                                                scleritis       0.67      1.00      0.80         2
#                                              scleroderma       1.00      0.67      0.80         3
#                                                scoliosis       1.00      0.67      0.80         3
#                                                   scurvy       0.00      0.00      0.00         2
#                           seasonal allergies (hay fever)       1.00      1.00      1.00         3
#                                           sebaceous cyst       1.00      0.50      0.67         4
#                                    seborrheic dermatitis       0.75      1.00      0.86         3
#                                     seborrheic keratosis       0.50      0.33      0.40         3
#                               sensorineural hearing loss       1.00      0.33      0.50         3
#                                                   sepsis       1.00      0.67      0.80         3
#                                         septic arthritis       1.00      1.00      1.00         2
#                                 shingles (herpes zoster)       0.50      0.33      0.40         3
#                                            sialoadenitis       1.00      1.00      1.00         3
#                                      sick sinus syndrome       0.75      1.00      0.86         3
#                                       sickle cell anemia       1.00      1.00      1.00         3
#                                       sickle cell crisis       1.00      1.00      1.00         3
#                                        sinus bradycardia       0.33      0.33      0.33         3
#                                         sjogren syndrome       1.00      1.00      1.00         2
#                                              skin cancer       0.67      0.67      0.67         3
#                                            skin disorder       1.00      0.67      0.80         3
#                               skin pigmentation disorder       0.40      0.67      0.50         3
#                                               skin polyp       0.25      0.33      0.29         3
#                             smoking or tobacco addiction       1.00      0.67      0.80         3
#                                            social phobia       0.60      1.00      0.75         3
#                                      soft tissue sarcoma       0.67      0.67      0.67         3
#                                    somatization disorder       1.00      0.50      0.67         2
#                                             spermatocele       0.33      0.50      0.40         2
#                                            spherocytosis       1.00      1.00      1.00         2
#                                             spina bifida       0.67      1.00      0.80         2
#                                          spinal stenosis       1.00      0.75      0.86         4
#                                   spinocerebellar ataxia       0.67      1.00      0.80         2
#                                              spondylitis       1.00      1.00      1.00         3
#                                        spondylolisthesis       0.75      1.00      0.86         3
#                                              spondylosis       1.00      0.50      0.67         4
#                                     spontaneous abortion       1.00      0.75      0.86         4
#                                           sporotrichosis       1.00      1.00      1.00         2
#                                         sprain or strain       0.67      0.50      0.57         4
#                                stenosis of the tear duct       1.00      0.50      0.67         2
#                                           stomach cancer       0.50      0.67      0.57         3
#                                             strep throat       0.67      1.00      0.80         4
#                                      stress incontinence       0.33      0.33      0.33         3
#                               stricture of the esophagus       1.00      1.00      1.00         2
#                                                   stroke       1.00      1.00      1.00         3
#                                                     stye       1.00      0.67      0.80         3
#                                     subacute thyroiditis       0.67      1.00      0.80         2
#                                  subarachnoid hemorrhage       0.67      1.00      0.80         2
#                               subconjunctival hemorrhage       1.00      0.33      0.50         3
#                                      subdural hemorrhage       1.00      1.00      1.00         2
#                        substance-related mental disorder       0.75      1.00      0.86         3
#       syndrome of inappropriate secretion of adh (siadh)       1.00      1.00      1.00         2
#                                                 syphilis       1.00      1.00      1.00         2
#                                            syringomyelia       0.00      0.00      0.00         2
#                       systemic lupus erythematosis (sle)       1.00      1.00      1.00         2
#                                        teething syndrome       1.00      1.00      1.00         3
#                       temporary or benign blood in urine       1.00      0.50      0.67         4
#                         temporomandibular joint disorder       0.60      1.00      0.75         3
#                                               tendinitis       1.00      0.33      0.50         3
#                                         tension headache       0.75      1.00      0.86         3
#                                        testicular cancer       1.00      1.00      1.00         2
#                                      testicular disorder       1.00      0.50      0.67         2
#                                       testicular torsion       1.00      1.00      1.00         2
#                                              thalassemia       1.00      1.00      1.00         2
#                                 thoracic aortic aneurysm       0.50      0.33      0.40         3
#                                 thoracic outlet syndrome       0.50      0.50      0.50         2
#                                     threatened pregnancy       0.75      1.00      0.86         3
#                                         thrombocytopenia       1.00      1.00      1.00         3
#                                         thrombophlebitis       1.00      1.00      1.00         3
#                                           thyroid cancer       1.00      1.00      1.00         2
#                                          thyroid disease       0.67      1.00      0.80         2
#                                           thyroid nodule       0.75      1.00      0.86         3
#                                  tic (movement) disorder       1.00      1.00      1.00         2
#                                          tietze syndrome       0.25      0.33      0.29         3
#                                tinnitus of unknown cause       1.00      0.67      0.80         3
#                                    tonsillar hypertrophy       1.00      0.67      0.80         3
#                                              tonsillitis       1.00      0.67      0.80         3
#                                            tooth abscess       1.00      1.00      1.00         3
#                                           tooth disorder       0.75      1.00      0.86         3
#                                              torticollis       1.00      1.00      1.00         3
#                                        tourette syndrome       1.00      1.00      1.00         2
#                                toxic multinodular goiter       1.00      1.00      1.00         2
#                                            toxoplasmosis       0.00      0.00      0.00         2
#                                               tracheitis       1.00      1.00      1.00         3
#                                transient ischemic attack       0.75      1.00      0.86         3
#                                               trichiasis       0.67      1.00      0.80         2
#                                              trichinosis       0.00      0.00      0.00         2
#                                    trichomonas infection       1.00      0.67      0.80         3
#                                  tricuspid valve disease       0.00      0.00      0.00         2
#                                     trigeminal neuralgia       0.50      0.33      0.40         3
#                         trigger finger (finger disorder)       1.00      1.00      1.00         2
#                                             tuberculosis       1.00      1.00      1.00         2
#                                       tuberous sclerosis       1.00      0.50      0.67         2
#                                          turner syndrome       1.00      1.00      1.00         2
#                                            typhoid fever       1.00      1.00      1.00         2
#                                       ulcerative colitis       1.00      1.00      1.00         3
#                                        urethral disorder       1.00      0.67      0.80         3
#                                       urethral stricture       1.00      1.00      1.00         3
#                                          urethral valves       1.00      1.00      1.00         2
#                                               urethritis       1.00      0.67      0.80         3
#                                        urge incontinence       0.40      0.67      0.50         3
#                                  urinary tract infection       0.33      0.33      0.33         3
#                                urinary tract obstruction       1.00      1.00      1.00         3
#                                            uterine atony       0.60      1.00      0.75         3
#                                           uterine cancer       0.67      1.00      0.80         2
#                                         uterine fibroids       1.00      0.67      0.80         3
#                                                  uveitis       0.25      1.00      0.40         2
#                                         vacterl syndrome       1.00      1.00      1.00         2
#                                             vaginal cyst       1.00      0.75      0.86         4
#                                  vaginal yeast infection       1.00      0.67      0.80         3
#                                               vaginismus       1.00      1.00      1.00         2
#                                                vaginitis       0.75      1.00      0.86         3
#                                             valley fever       1.00      1.00      1.00         2
#                              varicocele of the testicles       1.00      0.67      0.80         3
#                                           varicose veins       0.75      1.00      0.86         3
#                                               vasculitis       1.00      0.67      0.80         3
#                                     venous insufficiency       1.00      1.00      1.00         3
#                            vertebrobasilar insufficiency       0.00      0.00      0.00         2
#                                    vesicoureteral reflux       1.00      0.50      0.67         2
#                                           viral exanthem       0.43      1.00      0.60         3
#                                          viral hepatitis       0.67      1.00      0.80         2
#                                              viral warts       1.00      1.00      1.00         3
#                                     vitamin a deficiency       1.00      1.00      1.00         2
#                                   vitamin b12 deficiency       1.00      0.50      0.67         2
#                                     vitamin d deficiency       0.00      0.00      0.00         2
#                                    vitreous degeneration       1.00      0.33      0.50         3
#                                      vitreous hemorrhage       0.00      0.00      0.00         2
#                                         vocal cord polyp       1.00      0.50      0.67         2
#                                                 volvulus       0.00      0.00      0.00         2
#                                   von willebrand disease       1.00      1.00      1.00         2
#                                            vulvar cancer       0.50      0.50      0.50         2
#                                          vulvar disorder       1.00      1.00      1.00         2
#                                               vulvodynia       1.00      1.00      1.00         4
#                              wernicke korsakoff syndrome       0.00      0.00      0.00         2
#                                 white blood cell disease       0.75      1.00      0.86         3
#                                           whooping cough       0.50      0.50      0.50         2
#                                           wilson disease       0.50      0.50      0.50         2
#                                          yeast infection       0.75      1.00      0.86         3
#                                      zenker diverticulum       1.00      1.00      1.00         2
#
#                                                 accuracy                           0.76      2119
#                                                macro avg       0.81      0.77      0.76      2119
#                                             weighted avg       0.81      0.76      0.76      2119
# ['scaler.pkl']

# %%
import joblib
import numpy as np
import pandas as pd
import os

# Load necessary artifacts (symptom columns and class names)
symptom_cols = joblib.load("symptom_cols.pkl")
# class_names = joblib.load("class_names.pkl") # Original line
# Assuming you used a scaler, uncomment the line below
# scaler = joblib.load("scaler.pkl")
# Assuming you used a label encoder for the target, uncomment the line below
label_encoder = joblib.load("label_encoder.pkl")


# Function to get user input for symptoms
def get_user_symptoms():
    print("Enter the symptoms you are experiencing, separated by commas:")
    symptoms_input = input()
    # Clean and split the input symptoms
    user_symptoms = [symptom.strip().lower() for symptom in symptoms_input.split(',') if symptom.strip()]
    return user_symptoms

# Function to preprocess user symptoms
def preprocess_user_symptoms(user_symptoms, symptom_cols):
    # Create a zero vector with the same length as the model's symptom columns
    input_vector = pd.DataFrame(0, index=[0], columns=symptom_cols)

    # Mark the presence of user-provided symptoms with 1
    # Sanitize user input symptoms to match the format of symptom_cols
    sanitized_user_symptoms = [s.replace(" ", "_") for s in user_symptoms]

    for symptom in sanitized_user_symptoms:
        if symptom in input_vector.columns:
            input_vector[symptom] = 1
        else:
            print(f"Warning: Symptom '{symptom}' not found in the known symptoms.")

    # If you used a scaler during training, uncomment and apply it here
    # input_vector_scaled = scaler.transform(input_vector)
    # return input_vector_scaled

    return input_vector


# Get symptoms from the user
user_symptoms = get_user_symptoms()

# Preprocess the user symptoms
input_data = preprocess_user_symptoms(user_symptoms, symptom_cols)

# Define the list of trained models
model_files = [
    "RandomForest_model.pkl"
]

# Iterate through each model and make a prediction
for model_file in model_files:
    if os.path.exists(model_file):
        print(f"\n--- Predictions using {model_file.replace('_model.pkl', '')} ---")
        model = joblib.load(model_file)

        # Handle scaling for MLP and Logistic Regression if scaler was used
        # if model_file in ["MLPClassifier_model.pkl", "LogisticRegression_model.pkl"] and 'scaler' in locals():
        #     input_data_processed = scaler.transform(input_data)
        # else:
        #     input_data_processed = input_data

        # Handle TabNet input format
        input_data_processed = input_data


        # Make a prediction
        predicted_disease_encoded = model.predict(input_data_processed)

        # Decode the prediction if label encoding was used
        if 'label_encoder' in locals():
            predicted_disease = label_encoder.inverse_transform(predicted_disease_encoded)[0]
        else:
            predicted_disease = predicted_disease_encoded[0] # Fallback if no label encoder

        print(f"Predicted Disease: {predicted_disease}")

        # Optional: Get prediction probabilities to show top N diseases
        if hasattr(model, 'predict_proba'):
            probabilities = model.predict_proba(input_data_processed)[0]
            top_n = 5
            top_indices = np.argsort(probabilities)[::-1][:top_n]
            print("Top 5 possible diseases:")
            # Use the label encoder's classes for decoding
            if 'label_encoder' in locals():
                for i in top_indices:
                    print(f"- {label_encoder.classes_[i]}: {probabilities[i]*100:.2f}%")
            elif hasattr(model, 'classes_'):
                 for i in top_indices:
                    print(f"- {model.classes_[i]}: {probabilities[i]*100:.2f}%")
            else:
                 print("Cannot retrieve class names for top predictions.")

    else:
        print(f"\nWarning: Model file '{model_file}' not found. Skipping.")
# Out:
# Enter the symptoms you are experiencing, separated by commas:
#
# --- Predictions using RandomForest ---
# Predicted Disease: erythema multiforme
# Top 5 possible diseases:
# - erythema multiforme: 61.00%
# - chickenpox: 12.00%
# - diaper rash: 5.00%
# - Drug Reaction: 4.00%
# - mononucleosis: 3.00%

# %%
import joblib
import numpy as np
import pandas as pd
import re

# Load assets
symptom_cols = joblib.load("symptom_cols.pkl")
label_encoder = joblib.load("label_encoder.pkl")
model = joblib.load("RandomForest_model.pkl")

# Extract symptoms from free-form user input
def extract_symptoms_from_text(text, known_symptoms):
    text = text.lower()
    text = re.sub(r"[^a-zA-Z0-9_ ]", "", text)  # remove punctuation
    found_symptoms = []
    for symptom in known_symptoms:
        if symptom.lower().replace("_", " ") in text:
            found_symptoms.append(symptom)
    return found_symptoms

# Convert extracted symptoms to binary input vector
def symptoms_to_input_vector(symptoms, all_symptom_cols):
    input_vector = pd.DataFrame(0, index=[0], columns=all_symptom_cols)
    for symptom in symptoms:
        if symptom in input_vector.columns:
            input_vector.at[0, symptom] = 1
    return input_vector

# ==== USER INPUT EXAMPLE ====
user_input = input("Describe your symptoms: ")  # e.g. "I have a fever and severe headache"

# Extract and vectorize
extracted_symptoms = extract_symptoms_from_text(user_input, symptom_cols)
input_vector = symptoms_to_input_vector(extracted_symptoms, symptom_cols)

# Predict
if extracted_symptoms:
    probs = model.predict_proba(input_vector)[0]
    top_n = 5
    top_indices = np.argsort(probs)[::-1][:top_n]
    print("\nTop probable diseases:")
    for i in top_indices:
        print(f"- {label_encoder.classes_[i]}: {probs[i]*100:.2f}%")
else:
    print("⚠️ No recognizable symptoms found in your input.")
# Out:
# Top probable diseases:
# - pharyngitis: 22.53%
# - otitis media: 20.13%
# - noninfectious gastroenteritis: 11.00%
# - strep throat: 5.00%
# - infectious gastroenteritis: 4.00%

# %%
import pandas as pd

df = pd.read_csv("combined_dataset.csv")
df.columns = df.columns.str.strip()

# All symptom columns (excluding 'diseases')
symptom_cols = [col for col in df.columns if col != "diseases"]

# Create mapping: disease -> all associated symptoms
disease_symptom_map = {}

for disease, group in df.groupby("diseases"):
    present_symptoms = group[symptom_cols].sum()
    relevant = present_symptoms[present_symptoms > 0].index.tolist()
    disease_symptom_map[disease] = relevant


import joblib
joblib.dump(disease_symptom_map, "disease_symptom_map.pkl")
# Out:
# ['disease_symptom_map.pkl']

# %%
import pandas as pd
import google.generativeai as genai
import json

# Configure Gemini API key
genai.configure(api_key="AIzaSyA5pOowHQoCsuXhQhFIQ4uLKtjPB6y3iRo")  # Replace with your actual key
model = genai.GenerativeModel("gemini-2.5-pro")

# Load dataset and get first 5 diseases
df = pd.read_csv("combined_dataset.csv")
unique_diseases = sorted(df["diseases"].dropna().unique())[:5]

disease_info = {}

# Loop through and get info from Gemini
for disease in unique_diseases:
    prompt = (
        f"Give a brief description and 2-3 key precautions for the disease: {disease}. "
        "Make it concise. Just write the disease name, its description and Precautions in points."
    )
    print(f"\n🦠 {disease}")
    try:
        response = model.generate_content(prompt)
        print(response.text)
    except Exception as e:
        print(f"[Error] {e}")

with open("disease_info.json", "w", encoding="utf-8") as f:
    json.dump(disease_info, f, indent=2, ensure_ascii=False)

print("\n✅ Saved results to disease_info.json")
# Out:
# 🦠 (vertigo) Paroymsal  Positional Vertigo
# [Error] 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
#
# 🦠 AIDS
# [Error] Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 1.
#
# 🦠 Acne
# [Error] Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 1.
#
# 🦠 Alcoholic hepatitis
# [Error] 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 2
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
#
# 🦠 Allergy
# [Error] Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 1.
#
# ✅ Saved results to disease_info.json
